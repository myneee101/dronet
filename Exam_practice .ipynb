# %%
import pandas as pd
import numpy as np
# Load libraries
from pandas import read_csv
from pandas.plotting import scatter_matrix
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
import csv
with open('seeds_dataset.txt','r') as in_file:
    stripped =(line.strip() for line in in_file)
    lines =(line.split(",") for line in stripped if line)
    with open('myncsv.csv','w') as out_file: 
        writer = csv.writer(out_file)
        writer.writerows(lines)

# %%
data = pd.read_csv("log.csv")

# %%
data.head(10)
# Out:
#    15.26\t14.84\t0.871\t5.763\t3.312\t2.221\t5.22\t1
# 0  14.88\t14.57\t0.8811\t5.554\t3.333\t1.018\t4.9...
# 1  14.29\t14.09\t0.905\t5.291\t3.337\t2.699\t4.82...
# 2  13.84\t13.94\t0.8955\t5.324\t3.379\t2.259\t4.8...
# 3  16.14\t14.99\t0.9034\t5.658\t3.562\t1.355\t5.1...
# 4  14.38\t14.21\t0.8951\t5.386\t3.312\t2.462\t4.9...
# 5  14.69\t14.49\t0.8799\t5.563\t3.259\t3.586\t5.2...
# 6    14.11\t14.1\t0.8911\t5.42\t3.302\t2.7\t\t5\t\t1
# 7  16.63\t15.46\t0.8747\t6.053\t3.465\t2.04\t5.87...
# 8  16.44\t15.25\t0.888\t5.884\t3.505\t1.969\t5.53...
# 9  15.26\t14.85\t0.8696\t5.714\t3.242\t4.543\t5.3...

# %%
# importing panda library
import pandas as pd
  
# readinag given csv file
# and creating dataframe
dataframe1 = pd.read_csv("seeds_dataset.txt")
  
# storing this dataframe in a csv file
dataframe1.to_csv('seeds.csv', 
                  index = None)

# %%
data1 = pd.read_csv("seeds.csv")

# %%
data.head(10)
# Out:
#    15.26\t14.84\t0.871\t5.763\t3.312\t2.221\t5.22\t1
# 0  14.88\t14.57\t0.8811\t5.554\t3.333\t1.018\t4.9...
# 1  14.29\t14.09\t0.905\t5.291\t3.337\t2.699\t4.82...
# 2  13.84\t13.94\t0.8955\t5.324\t3.379\t2.259\t4.8...
# 3  16.14\t14.99\t0.9034\t5.658\t3.562\t1.355\t5.1...
# 4  14.38\t14.21\t0.8951\t5.386\t3.312\t2.462\t4.9...
# 5  14.69\t14.49\t0.8799\t5.563\t3.259\t3.586\t5.2...
# 6    14.11\t14.1\t0.8911\t5.42\t3.302\t2.7\t\t5\t\t1
# 7  16.63\t15.46\t0.8747\t6.053\t3.465\t2.04\t5.87...
# 8  16.44\t15.25\t0.888\t5.884\t3.505\t1.969\t5.53...
# 9  15.26\t14.85\t0.8696\t5.714\t3.242\t4.543\t5.3...

# %%
# importing pandas library
import pandas as pd
  
# reading the given csv file 
# and creating dataframe
account = pd.read_csv("seeds_dataset.txt",
                      delimiter = ' ')
  
# store dataframe into csv file
account.to_csv('Geek1.csv',
               index = None)

# %%
data22 = pd.read_csv("Geek1.csv")

# %%
data22.head(10)
# Out:
#    15.26\t14.84\t0.871\t5.763\t3.312\t2.221\t5.22\t1
# 0  14.88\t14.57\t0.8811\t5.554\t3.333\t1.018\t4.9...
# 1  14.29\t14.09\t0.905\t5.291\t3.337\t2.699\t4.82...
# 2  13.84\t13.94\t0.8955\t5.324\t3.379\t2.259\t4.8...
# 3  16.14\t14.99\t0.9034\t5.658\t3.562\t1.355\t5.1...
# 4  14.38\t14.21\t0.8951\t5.386\t3.312\t2.462\t4.9...
# 5  14.69\t14.49\t0.8799\t5.563\t3.259\t3.586\t5.2...
# 6    14.11\t14.1\t0.8911\t5.42\t3.302\t2.7\t\t5\t\t1
# 7  16.63\t15.46\t0.8747\t6.053\t3.465\t2.04\t5.87...
# 8  16.44\t15.25\t0.888\t5.884\t3.505\t1.969\t5.53...
# 9  15.26\t14.85\t0.8696\t5.714\t3.242\t4.543\t5.3...

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
# Load dataset
load_data = "pima-indians-diabetes.csv"
names = ['Pregnancies', ' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI',' DiPed','Age','class']
df = read_csv(load_data, names=names)

# %%
df.head()
# Out:
#    Pregnancies   Glucose  BloodPressure   SkinThickness   Insulin   BMI  \
# 0            6       148             72              35         0  33.6
# 1            1        85             66              29         0  26.6
# 2            8       183             64               0         0  23.3
# 3            1        89             66              23        94  28.1
# 4            0       137             40              35       168  43.1
#
#     DiPed  Age  class
# 0   0.627   50      1
# 1   0.351   31      0
# 2   0.672   32      1
# 3   0.167   21      0
# 4   2.288   33      1

# %%
df.describe()
# Out:
#        Pregnancies       Glucose  BloodPressure   SkinThickness     Insulin  \
# count   768.000000    768.000000     768.000000      768.000000  768.000000
# mean      3.940104    380.910156      69.105469       20.536458   79.799479
# std       4.324703   5093.663558      19.355807       15.952218  115.244002
# min       0.000000      0.000000       0.000000        0.000000    0.000000
# 25%       1.000000     99.000000      62.000000        0.000000    0.000000
# 50%       3.000000    117.000000      72.000000       23.000000   30.500000
# 75%       6.000000    141.000000      80.000000       32.000000  127.250000
# max      79.000000  99999.000000     122.000000       99.000000  846.000000
#
#               BMI       DiPed         Age       class
# count  768.000000  768.000000  768.000000  768.000000
# mean    32.831771    0.535888   33.319010    0.348958
# std     18.190821    1.817614   11.995482    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# ...

# %%
raw_indices=df.loc[(df.values==99999).any(axis=1)].index.tolist()
print(raw_indices)
# Out:
# [500, 549]

# %%
No_of_missing_value = (df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']] ==0).sum() + (df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']] == 99999).sum() 
No_of_missing_value
# Out:
#  Glucose            7
# BloodPressure      35
#  SkinThickness    227
#  Insulin          374
#  BMI               11
# dtype: int64

# %%
(abs(df-df.mean())>3*df.std()).sum()
# Out:
# Pregnancies        2
#  Glucose           2
# BloodPressure     35
#  SkinThickness     1
#  Insulin          18
#  BMI               2
#  DiPed             1
# Age                4
# class              0
# dtype: int64

# %%
df.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False, figsize=(10,10))
df.hist(figsize=(10,10))
plt.show()

# %%
df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']]=df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']].replace(0,np.nan)

# %%
df
# Out:
#      Pregnancies   Glucose  BloodPressure   SkinThickness   Insulin   BMI  \
# 0              6     148.0           72.0            35.0       NaN  33.6
# 1              1      85.0           66.0            29.0       NaN  26.6
# 2              8     183.0           64.0             NaN       NaN  23.3
# 3              1      89.0           66.0            23.0      94.0  28.1
# 4              0     137.0           40.0            35.0     168.0  43.1
# ..           ...       ...            ...             ...       ...   ...
# 763           10     101.0           76.0            48.0     180.0  32.9
# 764            2     122.0           70.0            27.0       NaN  36.8
# 765            5     121.0           72.0            23.0     112.0  26.2
# 766            1     126.0           60.0             NaN       NaN  30.1
# 767            1      93.0           70.0            31.0       NaN  30.4
#
#       DiPed  Age  class
# 0     0.627   50      1
# 1     0.351   31      0
# ...

# %%
df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']]=df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']].replace(99999,np.nan)

# %%
df
# Out:
#      Pregnancies   Glucose  BloodPressure   SkinThickness   Insulin   BMI  \
# 0              6     148.0           72.0            35.0       NaN  33.6
# 1              1      85.0           66.0            29.0       NaN  26.6
# 2              8     183.0           64.0             NaN       NaN  23.3
# 3              1      89.0           66.0            23.0      94.0  28.1
# 4              0     137.0           40.0            35.0     168.0  43.1
# ..           ...       ...            ...             ...       ...   ...
# 763           10     101.0           76.0            48.0     180.0  32.9
# 764            2     122.0           70.0            27.0       NaN  36.8
# 765            5     121.0           72.0            23.0     112.0  26.2
# 766            1     126.0           60.0             NaN       NaN  30.1
# 767            1      93.0           70.0            31.0       NaN  30.4
#
#       DiPed  Age  class
# 0     0.627   50      1
# 1     0.351   31      0
# ...

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure   SkinThickness     Insulin  \
# count   768.000000  761.000000     733.000000      541.000000  394.000000
# mean      3.940104  121.604468      72.405184       29.153420  155.548223
# std       4.324703   30.477557      12.382158       10.476982  118.775855
# min       0.000000   44.000000      24.000000        7.000000   14.000000
# 25%       1.000000   99.000000      64.000000       22.000000   76.250000
# 50%       3.000000  117.000000      72.000000       29.000000  125.000000
# 75%       6.000000  141.000000      80.000000       36.000000  190.000000
# max      79.000000  199.000000     122.000000       99.000000  846.000000
#
#               BMI       DiPed         Age       class
# count  757.000000  768.000000  768.000000  768.000000
# mean    33.308851    0.535888   33.319010    0.348958
# std     17.883197    1.817614   11.995482    0.476951
# min     18.200000    0.078000   21.000000    0.000000
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      Pregnancies   Glucose  BloodPressure   SkinThickness   Insulin   BMI  \
# 3              1      89.0           66.0            23.0      94.0  28.1
# 4              0     137.0           40.0            35.0     168.0  43.1
# 6              3      78.0           50.0            32.0      88.0  31.0
# 8              2     197.0           70.0            45.0     543.0  30.5
# 13             1     189.0           60.0            23.0     846.0  30.1
# ..           ...       ...            ...             ...       ...   ...
# 753            0     181.0           88.0            44.0     510.0  43.3
# 755            1     128.0           88.0            39.0     110.0  36.5
# 760            2      88.0           58.0            26.0      16.0  28.4
# 763           10     101.0           76.0            48.0     180.0  32.9
# 765            5     121.0           72.0            23.0     112.0  26.2
#
#       DiPed  Age  class
# 3     0.167   21      0
# 4     2.288   33      1
# ...

# %%
df.plot(kind='box', subplots=True, layout=(3,3), sharex=False, sharey=False,figsize=(10,10)) 
df.hist(figsize=(10,10)) 
plt.show()

# %% [markdown]
# # Univariate Selection

# %%
from pandas import read_csv
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
# Load dataset
load_data = "pima-indians-diabetes.csv"
names = ['Pregnancies', ' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI',' DiPed','Age','class']
df = read_csv(load_data, names=names)
array = df.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
test = SelectKBest(score_func=chi2, k=4)
fit = test.fit(X, Y)
# summarize scores
set_printoptions(precision=3)
print(fit.scores_)
# Out:
# [8.950e+01 6.207e+04 1.761e+01 5.311e+01 2.176e+03 6.695e+01 1.640e-01
#  1.736e+02]

# %% [markdown]
# # Feature Extraction with PCA

# %%
# Feature Extraction with PCA
from pandas import read_csv
from sklearn.decomposition import PCA
# load data
load_data = "pima-indians-diabetes.csv"
names = ['Pregnancies', ' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI',' DiPed','Age','class']
dataframe = read_csv(load_data, names=names)
array = dataframe.values
X = array[:,0:8]
Y = array[:,8]
# feature extraction
pca = PCA(n_components=3)
fit = pca.fit(X)
# summarize components
print("Explained Variance:%s" % fit.explained_variance_ratio_)
print(fit.components_)
# Out:
# Explained Variance:[9.994e-01 5.136e-04 1.574e-05]
# [[-8.776e-06  1.000e+00  3.136e-04  4.589e-05 -3.975e-04  1.824e-03
#   -2.570e-07 -3.945e-05]
#  [-1.315e-03  3.557e-04  1.586e-02  6.145e-02  9.978e-01  1.812e-02
#    1.102e-03 -3.684e-03]
#  [ 5.592e-02 -8.225e-04  8.974e-01  2.569e-01 -3.449e-02  2.874e-01
#    1.641e-02  2.039e-01]]

# %% [markdown]
# #  SVM Classification Model before removing

# %%
import pandas as pd 
import numpy as np 
from sklearn.svm import SVC 
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import StratifiedKFold 
from sklearn.model_selection import train_test_split 
load_data = "pima-indians-diabetes.csv"
names = ['Pregnancies', ' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI',' DiPed','Age','class']
df = read_csv(load_data, names=names)
array = df.values
X = array[:,0:8] 
Y = array[:,8] 
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.30, 
random_state=1) 
models = [] 
models.append(('SVM', SVC(gamma='auto'))) 
results = [] 
names = [] 
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True) 
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy') 
    results.append(cv_results) 
    names.append(name) 
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# SVM: 0.659224 (0.007704)

# %%
model = SVC(gamma='auto')
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)

# %%
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 0.6320346320346321
# [[146   0]
#  [ 85   0]]
#               precision    recall  f1-score   support
#
#          0.0       0.63      1.00      0.77       146
#          1.0       0.00      0.00      0.00        85
#
#     accuracy                           0.63       231
#    macro avg       0.32      0.50      0.39       231
# weighted avg       0.40      0.63      0.49       231
# C:\Users\myneee101\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\myneee101\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# #  SVM Classification Model after removing

# %%
import pandas as pd 
import numpy as np 
from sklearn.svm import SVC 
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import StratifiedKFold 
from sklearn.model_selection import train_test_split 
load_data = "pima-indians-diabetes.csv"
names = ['Pregnancies', ' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI',' DiPed','Age','class']
df = read_csv(load_data, names=names)
df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']]=df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']].replace(0,np.nan)
df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']]=df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin',' BMI']].replace(99999,np.nan)
df.dropna(inplace=True)
array = df.values
X = array[:,0:8] 
Y = array[:,8] 
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.20, 
random_state=1) 
models = [] 
models.append(('SVM', SVC(gamma='auto'))) 
results = [] 
names = [] 
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True) 
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy') 
    results.append(cv_results) 
    names.append(name) 
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# SVM: 0.663508 (0.014432)

# %% [markdown]
# #  After the attributes are reduced

# %%
import pandas as pd 
import numpy as np 
from sklearn.svm import SVC 
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import StratifiedKFold 
from sklearn.model_selection import train_test_split 
from numpy import set_printoptions 
from sklearn.feature_selection import SelectKBest 
from sklearn.feature_selection import chi2 
load_data = "pima-indians-diabetes.csv"
names = ['Pregnancies', ' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin','Age','class']
df = read_csv(load_data, names=names)
df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin']]=df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin']].replace(0,np.nan)
df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin']]=df[[' Glucose', 'BloodPressure', ' SkinThickness', ' Insulin']].replace(99999,np.nan)
df.dropna(inplace=True)
array = df.values
X = array[:,0:6] 
Y = array[:,6] 
# feature extraction 
test = SelectKBest(score_func=chi2, k=4) 
fit = test.fit(X, Y) 
# summarize scores 
set_printoptions(precision=3) 
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.30, 
random_state=1) 
models = [] 
models.append(('SVM', SVC(gamma='auto'))) 
results = [] 
names = [] 
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True) 
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy') 
    results.append(cv_results) 
    names.append(name) 
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# SVM: 0.651058 (0.013304)

# %% [markdown]
# #  Replace the missing Values with mean of the columns

# %%
import pandas as pd 
import numpy as np 
from sklearn.svm import SVC 
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import StratifiedKFold 
from sklearn.model_selection import train_test_split 
from numpy import set_printoptions 
from sklearn.feature_selection import SelectKBest  
filename = "pima-indians-diabetes.csv"
names = ['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI', 'pedi', 'age', 'Outcome'] 
data = pd.read_csv(filename, names=names) 
data[['Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['Gluco', 'BPres', 'skin', 'Insulin', 'BMI']].replace(0, np.NaN) 
data[['Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['Gluco', 'BPres', 'skin', 'Insulin', 'BMI']].replace(99999, np.NaN) 
data.fillna(data.mean(), inplace=True) 
#print(data.isnull().sum()) 
array = data.values 
X = array[:,0:8] 
Y = array[:,8] 
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.30, 
random_state=1) 
models = [] 
models.append(('SVM', SVC(gamma='auto'))) 
results = [] 
names = [] 
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True) 
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy') 
    results.append(cv_results) 
    names.append(name) 
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# SVM: 0.657372 (0.011456)

# %% [markdown]
#  # Normalize all attributes

# %%
import pandas as pd 
import numpy as np 
filename = "pima-indians-diabetes.csv"
names = ['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI', 'pedi', 'age', 'Outcome'] 
data = pd.read_csv(filename, names=names) 
data[['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI']].replace(0, np.NaN) 
data[['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI']].replace(99999, np.NaN) 
data.fillna(data.mean(), inplace=True) 
#print(data.isnull().sum()) 
array = data.values 
for i in range(len(array[0])):
    value_min = min(array[:,i]) 
    value_max = max(array[:,i]) 
    min_max = value_max - value_min 
    if (i != 6 and i != 8):
        array [:,i]= array [:,i]/ min_max
X = array[:,0:8] 
Y = array[:,8] 
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.20, random_state=1) 
models = [] 
models.append(('SVM', SVC(gamma='auto'))) 
results = [] 
names = [] 
for name, model in models: 
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True) 
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy') 
    results.append(cv_results) 
    names.append(name) 
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# SVM: 0.749365 (0.044046)

# %%
model = SVC(gamma='auto')
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)

# %%
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 0.7662337662337663
# [[93  6]
#  [30 25]]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.94      0.84        99
#          1.0       0.81      0.45      0.58        55
#
#     accuracy                           0.77       154
#    macro avg       0.78      0.70      0.71       154
# weighted avg       0.77      0.77      0.75       154

# %%
import pandas as pd 
import numpy as np 
filename = "pima-indians-diabetes.csv"
names = ['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI', 'pedi', 'age', 'Outcome'] 
data = pd.read_csv(filename, names=names) 
data[['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI']].replace(0, np.NaN) 
data[['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI']].replace(99999, np.NaN) 
data.fillna(data.mean(), inplace=True) 
#print(data.isnull().sum()) 
 
for i in ['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI', 'age','Outcome']:
    max=data[i].max()
    min=data[i].min()
    x=list((data[i]-min)/(max-min))
    data[i]=x
array = data.values   
X = array[:,0:8] 
Y = array[:,8] 
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.20, 
random_state=1) 
models = [] 
models.append(('SVM', SVC(gamma='auto'))) 
results = [] 
names = [] 
for name, model in models: 
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True) 
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy') 
    results.append(cv_results) 
    names.append(name) 
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# SVM: 0.749365 (0.044046)

# %%
model = SVC(gamma='auto')
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)

# %%
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 0.7662337662337663
# [[93  6]
#  [30 25]]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.94      0.84        99
#          1.0       0.81      0.45      0.58        55
#
#     accuracy                           0.77       154
#    macro avg       0.78      0.70      0.71       154
# weighted avg       0.77      0.77      0.75       154

# %% [markdown]
# #

# %% [markdown]
# #  Standardize

# %%
import pandas as pd 
import numpy as np 
from sklearn.svm import SVC 
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import StratifiedKFold 
from sklearn.model_selection import train_test_split 
filename = "pima-indians-diabetes.csv" 
names = ['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI', 'pedi', 'age', 'Outcome'] 
data = pd.read_csv(filename, names=names) 
data[['Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['Gluco', 'BPres', 'skin', 'Insulin','BMI']].replace(0, np.NaN) 
data[['Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['Gluco', 'BPres', 'skin', 'Insulin','BMI']].replace(99999, np.NaN) 
data.fillna(data.mean(), inplace=True) 
#print(data.isnull().sum()) 
array = data.values
for i in range(len(array[0])):
    Means = (array [:,i]).mean() 
    Stdvs = (array [:,i]).std() 
    if (i != 1 and i != 2 and i !=8):
        array [:,i]= [array [:,i]- Means]/Stdvs 
X = array[:,0:8] 
Y = array[:,8] 
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.20, 
random_state=1) 
models = [] 
models.append(('SVM', SVC(gamma='auto'))) 
results = [] 
names = [] 
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True) 
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy') 
    results.append(cv_results) 
    names.append(name) 
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# SVM: 0.674220 (0.035437)

# %%
import pandas as pd 
import numpy as np 
from sklearn.svm import SVC 
from sklearn.model_selection import cross_val_score 
from sklearn.model_selection import StratifiedKFold 
from sklearn.model_selection import train_test_split 
filename = "pima-indians-diabetes.csv" 
names = ['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI', 'pedi', 'age', 'Outcome'] 
data = pd.read_csv(filename, names=names) 
data[['Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['Gluco', 'BPres', 'skin', 'Insulin','BMI']].replace(0, np.NaN) 
data[['Gluco', 'BPres', 'skin', 'Insulin', 'BMI']] = data[['Gluco', 'BPres', 'skin', 'Insulin','BMI']].replace(99999, np.NaN) 
data.fillna(data.mean(), inplace=True) 
#print(data.isnull().sum()) 
array = data.values
#standarization
for i in ['Gluco', 'BPres']:
    avg=data[['Gluco', 'BPres']].mean()
    sdev=data[['Gluco', 'BPres']].std()
    value=[['Gluco', 'BPres']]
    x=(((data[['Gluco', 'BPres']])-avg)/sdev)
    
X = array[:,0:8] 
Y = array[:,8] 
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=0.20, random_state=1) 
models = [] 
models.append(('SVM', SVC(gamma='auto'))) 
results = [] 
names = [] 
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True) 
    cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy') 
    results.append(cv_results) 
    names.append(name) 
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# SVM: 0.651507 (0.008881)

# %% [markdown]
# # Make predictions on validation dataset

# %%
model = SVC(gamma='auto')
model.fit(X_train, Y_train)
predictions = model.predict(X_validation)

# %% [markdown]
# # Evaluate predictions

# %%
print(accuracy_score(Y_validation, predictions))
print(confusion_matrix(Y_validation, predictions))
print(classification_report(Y_validation, predictions))
# Out:
# 0.6818181818181818
# [[93  6]
#  [43 12]]
#               precision    recall  f1-score   support
#
#          0.0       0.68      0.94      0.79        99
#          1.0       0.67      0.22      0.33        55
#
#     accuracy                           0.68       154
#    macro avg       0.68      0.58      0.56       154
# weighted avg       0.68      0.68      0.63       154

# %%
# compare algorithms
from pandas import read_csv
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# Load dataset
#url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/iris.csv"
#names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
#dataset = read_csv(url, names=names)



filename = "pima-indians-diabetes.csv" 
names = ['preg', 'Gluco', 'BPres', 'skin', 'Insulin', 'BMI', 'pedi', 'age', 'Outcome'] 
data = pd.read_csv(filename, names=names) 
 
array = data.values
X = array[:,0:8]
y = array[:,8]

# Split-out validation dataset
#array = dataset.values
#X = array[:,0:4]
#y = array[:,4]
X_train, X_validation, Y_train, Y_validation = train_test_split(X, y, test_size=0.20, random_state=1, shuffle=True)
# Spot Check Algorithms
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
# evaluate each model in turn
results = []
names = []
for name, model in models:
	kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
	cv_results = cross_val_score(model, X_train, Y_train, cv=kfold, scoring='accuracy')
	results.append(cv_results)
	names.append(name)
	print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Compare Algorithms
pyplot.boxplot(results, labels=names)
pyplot.title('Algorithm Comparison')
pyplot.show()
# Out:
# C:\Users\myneee101\anaconda3\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# LR: 0.679244 (0.048877)
# LDA: 0.666261 (0.061545)
# KNN: 0.714781 (0.055334)
# CART: 0.679164 (0.039183)
# NB: 0.377684 (0.074761)
# SVM: 0.653120 (0.005458)
